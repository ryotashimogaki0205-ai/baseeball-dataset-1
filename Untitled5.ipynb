# %% [markdown]
# <a href="https://colab.research.google.com/github/ryotashimogaki0205-ai/baseeball-dataset-1/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import japanize_matplotlib
import matplotlib.patches as patches

# 投球位置の散布図
plt.figure(figsize=(8, 10)) # 縦長の長方形に変更
sns.scatterplot(x='pitch_x', y='pitch_y', hue='pitch_type', data=df, s=100, alpha=0.7) # hueを球種に変更
plt.title('投球位置と球種') # タイトルも変更
plt.xlabel('投球の左右位置 (捕手視点など)')
plt.ylabel('投球の高さ位置 (地面からなど)')
plt.grid(True)

# x軸とy軸の範囲を調整してボール球も含む
plt.xlim(-2.0, 2.0)
plt.ylim(-4.0, 4.0) # ストライクゾーンとボール球の範囲を考慮してy軸の表示範囲を調整

# ストライクゾーンを太線で囲む (x: -1.5から1.5, y: -2.5から2.5)
strike_zone = patches.Rectangle((-1.5, -2.5), 3.0, 5.0, linewidth=3, edgecolor='red', facecolor='none', linestyle='--')
plt.gca().add_patch(strike_zone)

# x軸とy軸を等間隔にする
plt.gca().set_aspect('equal', adjustable='box')

# 以前の補助線はストライクゾーンの範囲を示すため、今回は長方形で置き換えるため削除
# plt.axvline(0, color='gray', linestyle='--', linewidth=0.8)
# plt.axhline(2.5, color='gray', linestyle='--', linewidth=0.8)

plt.show()

# 打球方向ごとの打球速度の箱ひげ図
plt.figure(figsize=(8, 6))
sns.boxplot(x='ball_direction', y='exit_velocity', data=df)
plt.title('打球方向ごとの打球速度')
plt.xlabel('打球方向')
plt.ylabel('打球速度 (mph)')
plt.grid(axis='y')
plt.show()

# %%
display(df)
# Out:
#     pitch_x  pitch_y ball_direction  exit_velocity pitch_type
# 0       0.5     -1.0           Left             90   Fastball
# 1      -0.2      2.8         Center            105  Curveball
# 2       0.8      2.3          Right             88     Slider
# 3      -0.5      2.6           Left             95   Fastball
# 4       0.1      2.7         Center            110   Changeup
# 5       0.3      2.4          Right             85   Fastball
# 6      -0.7      2.9           Left             98  Curveball
# 7       0.6      2.2         Center            102     Slider
# 8      -0.1      2.5          Right             93   Changeup
# 9      -0.4      2.6         Center             80   Fastball
# 10     -0.8      2.0           Left            108   Fastball
# 11      0.1      3.1         Center             98  Curveball

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import japanize_matplotlib # 日本語表示のためにインポート
import matplotlib.patches as patches

# 打球方向ごとの投球位置と球種の散布図をファセットグリッドで表示
# col='ball_direction' で打球方向ごとにグラフを分割します。
# hue='pitch_type' で球種ごとに色分けします。

g = sns.relplot(x='pitch_x', y='pitch_y', hue='pitch_type', col='ball_direction', data=df, kind='scatter', s=100, alpha=0.7, col_wrap=3, height=5, aspect=0.8)

g.set_axis_labels('投球の左右位置', '投球の高さ位置')
g.set_titles(col_template='打球方向: {col_name}')
g.fig.suptitle('打球方向ごとの投球位置と球種', y=1.02) # 全体タイトル

# 各サブプロットにストライクゾーンを追加
for ax in g.axes.flat:
    strike_zone = patches.Rectangle((-1.5, -2.5), 3.0, 5.0, linewidth=1, edgecolor='red', facecolor='none', linestyle='--')
    ax.add_patch(strike_zone)
    ax.set_xlim(-2.0, 2.0)
    ax.set_ylim(-4.0, 4.0)
    ax.set_aspect('equal', adjustable='box')

plt.tight_layout() # レイアウトの調整
plt.show()

# %%
# 新しい打席データを入力するための「入力専用の表」 (複数行の追加も可能)
# 各辞書が1つの打席データを表します。
# 'pitch_x', 'pitch_y' でコースを、'pitch_type' で球種を指定します。
new_entries = [
    # 例:
    # {
    #     'pitch_x': -0.8,   # 例: 左低め
    #     'pitch_y': 2.0,    # 例: 低め
    #     'ball_direction': 'Left', # 例: 左方向
    #     'exit_velocity': 108, # 例: 108 mph
    #     'pitch_type': 'Fastball' # 例: ストレート
    # },
    # {
    #     'pitch_x': 0.1,    # 例: 真ん中高め
    #     'pitch_y': 3.1,    # 例: 高め
    #     'ball_direction': 'Center', # 例: センター方向
    #     'exit_velocity': 98,  # 例: 98 mph
    #     'pitch_type': 'Curveball' # 例: カーブ
    # },
    # ここに新しいデータを追加してください
    {
        'pitch_x': 0.7,
        'pitch_y': 1.5,
        'ball_direction': 'Right',
        'exit_velocity': 92,
        'pitch_type': 'Slider'
    }
]

# 新しいデータをDataFrameに変換
new_df_to_add = pd.DataFrame(new_entries)

# 既存のデータフレームに新しいデータを追加
df = pd.concat([df, new_df_to_add], ignore_index=True)

print("新しいデータが追加されました。データフレームの最後の5行:")
display(df.tail())
# Out:
# 新しいデータが追加されました。データフレームの最後の5行:
#     pitch_x  pitch_y ball_direction  exit_velocity pitch_type
# 8      -0.1      2.5          Right             93   Changeup
# 9      -0.4      2.6         Center             80   Fastball
# 10     -0.8      2.0           Left            108   Fastball
# 11      0.1      3.1         Center             98  Curveball
# 12      0.7      1.5          Right             92     Slider

# %%
# 新しい打席データを入力する「入力専用の表」 (複数行の追加も可能)
# 各辞書が1つの打席データを表します。
# 'pitch_x', 'pitch_y' でコースを、'pitch_type' で球種を指定します。
new_entries = [
    {
        'pitch_x': -0.8,   # 例: 左低め
        'pitch_y': 2.0,    # 例: 低め
        'ball_direction': 'Left', # 例: 左方向
        'exit_velocity': 108, # 例: 108 mph
        'pitch_type': 'Fastball' # 例: ストレート
    },
    {
        'pitch_x': 0.1,    # 例: 真ん中高め
        'pitch_y': 3.1,    # 例: 高め
        'ball_direction': 'Center', # 例: センター方向
        'exit_velocity': 98,  # 例: 98 mph
        'pitch_type': 'Curveball' # 例: カーブ
    },
    # 必要に応じて、さらに新しいデータをここに追加してください
    # 'pitch_type'には、既存の球種だけでなく、新しい球種（例: 'Knuckleball'）も入力できます。
    # {
    #     'pitch_x': 任意のx座標,
    #     'pitch_y': 任意のy座標,
    #     'ball_direction': 'Left', 'Center', 'Right' のいずれか,
    #     'exit_velocity': 任意の打球速度,
    #     'pitch_type': 'Fastball', 'Curveball', 'Slider', 'Changeup', 'Knuckleball' など
    # }
]

# 新しいデータをDataFrameに変換
new_df = pd.DataFrame(new_entries)

# 既存のデータフレームに新しいデータを追加
df = pd.concat([df, new_df], ignore_index=True)

print("新しいデータが追加されました。データフレームの最後の5行:")
display(df.tail())
# Out:
# 新しいデータが追加されました。データフレームの最後の5行:
#     pitch_x  pitch_y ball_direction  exit_velocity pitch_type
# 10     -0.8      2.0           Left            108   Fastball
# 11      0.1      3.1         Center             98  Curveball
# 12      0.7      1.5          Right             92     Slider
# 13     -0.8      2.0           Left            108   Fastball
# 14      0.1      3.1         Center             98  Curveball

# %% [markdown]
# ### ⚾️ 野球データ分析ツール
#
# このツールは、打席データ（投球位置、球種、打球方向、打球速度）を入力し、その傾向を視覚化するためのものです。
#
# ---

# %% [markdown]
# #### 1. 初期設定とデータフレームの準備
#
# 必要なライブラリをインポートし、データフレームを初期化します。データフレームは、新しいデータを追加していくための土台となります。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import japanize_matplotlib # 日本語表示のためにインポート
import matplotlib.patches as patches

# データフレームの初期化
# 既存のデータがない状態で始める場合は、空のデータフレームを作成します。
# カラム名を定義しておくことで、新しいデータ追加時にエラーを防ぎます。
if 'df' not in locals():
    df = pd.DataFrame(columns=['pitch_x', 'pitch_y', 'ball_direction', 'exit_velocity', 'pitch_type'])

print("データフレームが準備できました。")
# Out:
# データフレームが準備できました。

# %% [markdown]
# #### 2. 新しい打席データを入力
#
# 以下の `new_entries` リストに新しい打席データを追加してください。複数行のデータを一度に追加できます。
#
# *   `pitch_x`: 投球の左右位置（捕手視点など）
# *   `pitch_y`: 投球の高さ位置（地面からなど）
# *   `ball_direction`: 打球方向 ('Left', 'Center', 'Right' のいずれか)
# *   `exit_velocity`: 打球速度 (mph)
# *   `pitch_type`: 球種 ('Fastball', 'Curveball', 'Slider', 'Changeup' など)
#
# データを追加したら、このセルを実行してください。

# %%
# 新しい打席データを入力するための「入力専用の表」
new_entries = [
    # ここに新しいデータを追加してください (例を参考に記述してください)
    {
        'pitch_x': -0.8,   # 例: 左低め
        'pitch_y': 2.0,    # 例: 低め
        'ball_direction': 'Left', # 例: 左方向
        'exit_velocity': 108, # 例: 108 mph
        'pitch_type': 'Fastball' # 例: ストレート
    },
    {
        'pitch_x': 0.1,    # 例: 真ん中高め
        'pitch_y': 3.1,    # 例: 高め
        'ball_direction': 'Center', # 例: センター方向
        'exit_velocity': 98,  # 例: 98 mph
        'pitch_type': 'Curveball' # 例: カーブ
    }
    # 必要に応じて、さらにデータを追加
]

# 新しいデータをDataFrameに変換
new_df_to_add = pd.DataFrame(new_entries)

# 既存のデータフレームに新しいデータを追加
df = pd.concat([df, new_df_to_add], ignore_index=True)

print("新しいデータが追加されました。データフレームの最後の5行:")
display(df.tail())
# Out:
# 新しいデータが追加されました。データフレームの最後の5行:
#     pitch_x  pitch_y ball_direction  exit_velocity pitch_type
# 12      0.7      1.5          Right             92     Slider
# 13     -0.8      2.0           Left            108   Fastball
# 14      0.1      3.1         Center             98  Curveball
# 15     -0.8      2.0           Left            108   Fastball
# 16      0.1      3.1         Center             98  Curveball

# %% [markdown]
# #### 3. データフレームの確認
#
# 現在のデータフレームの全体を表示します。

# %%
display(df)
# Out:
#     pitch_x  pitch_y ball_direction  exit_velocity pitch_type
# 0       0.5     -1.0           Left             90   Fastball
# 1      -0.2      2.8         Center            105  Curveball
# 2       0.8      2.3          Right             88     Slider
# 3      -0.5      2.6           Left             95   Fastball
# 4       0.1      2.7         Center            110   Changeup
# 5       0.3      2.4          Right             85   Fastball
# 6      -0.7      2.9           Left             98  Curveball
# 7       0.6      2.2         Center            102     Slider
# 8      -0.1      2.5          Right             93   Changeup
# 9      -0.4      2.6         Center             80   Fastball
# 10     -0.8      2.0           Left            108   Fastball
# 11      0.1      3.1         Center             98  Curveball
# 12      0.7      1.5          Right             92     Slider
# 13     -0.8      2.0           Left            108   Fastball
# 14      0.1      3.1         Center             98  Curveball
# 15     -0.8      2.0           Left            108   Fastball
# 16      0.1      3.1         Center             98  Curveball

# %% [markdown]
# #### 4. 各分析グラフの表示
#
# 入力されたデータに基づいて、各種分析グラフを表示します。データを追加・更新した場合は、以下のセルを再実行してください。

# %% [markdown]
# ##### 4.1 投球位置と球種
#
# ストライクゾーンを破線で表示し、各球種の投球位置を散布図で示します。

# %%
# 投球位置の散布図
plt.figure(figsize=(8, 10)) # 縦長の長方形に変更
sns.scatterplot(x='pitch_x', y='pitch_y', hue='pitch_type', data=df, s=100, alpha=0.7) # hueを球種に変更
plt.title('投球位置と球種') # タイトルも変更
plt.xlabel('投球の左右位置 (捕手視点など)')
plt.ylabel('投球の高さ位置 (地面からなど)')
plt.grid(True)

# x軸とy軸の範囲を調整してボール球も含む
plt.xlim(-2.0, 2.0)
plt.ylim(-4.0, 4.0) # ストライクゾーンとボール球の範囲を考慮してy軸の表示範囲を調整

# ストライクゾーンを太線で囲む (x: -1.5から1.5, y: -2.5から2.5)
strike_zone = patches.Rectangle((-1.5, -2.5), 3.0, 5.0, linewidth=3, edgecolor='red', facecolor='none', linestyle='--')
plt.gca().add_patch(strike_zone)

# x軸とy軸を等間隔にする
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %% [markdown]
# ##### 4.2 打球方向ごとの打球速度
#
# 打球方向ごとの打球速度の分布を箱ひげ図で表示します。

# %%
# 打球方向ごとの打球速度の箱ひげ図
plt.figure(figsize=(8, 6))
sns.boxplot(x='ball_direction', y='exit_velocity', data=df)
plt.title('打球方向ごとの打球速度')
plt.xlabel('打球方向')
plt.ylabel('打球速度 (mph)')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ##### 4.3 打球方向ごとの投球位置と球種 (ファセットグリッド)
#
# 打球方向ごとに投球位置と球種の関係を細かく分析します。各打球方向における投球コースの傾向を把握できます。

# %%
# 打球方向ごとの投球位置と球種の散布図をファセットグリッドで表示
# col='ball_direction' で打球方向ごとにグラフを分割します。
# hue='pitch_type' で球種ごとに色分けします。

g = sns.relplot(x='pitch_x', y='pitch_y', hue='pitch_type', col='ball_direction', data=df, kind='scatter', s=100, alpha=0.7, col_wrap=3, height=5, aspect=0.8)

g.set_axis_labels('投球の左右位置', '投球の高さ位置')
g.set_titles(col_template='打球方向: {col_name}')
g.fig.suptitle('打球方向ごとの投球位置と球種', y=1.02) # 全体タイトル

# 各サブプロットにストライクゾーンを追加
for ax in g.axes.flat:
    strike_zone = patches.Rectangle((-1.5, -2.5), 3.0, 5.0, linewidth=1, edgecolor='red', facecolor='none', linestyle='--')
    ax.add_patch(strike_zone)
    ax.set_xlim(-2.0, 2.0)
    ax.set_ylim(-4.0, 4.0)
    ax.set_aspect('equal', adjustable='box')

plt.tight_layout() # レイアウトの調整
plt.show()

# %% [markdown]
# # Task
# ウェブアプリケーション構築に関するColabの限界と、ウェブアプリケーションを開発するための一般的なステップ（フレームワークの利用、ホスティングサービスへのデプロイ）を説明し、Colabノートブック内でのデータ分析や可視化に関する追加の要望がないかを確認する。

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# ユーザーがウェブアプリケーションについて尋ねた内容に対して、現在のColab環境の限界とウェブアプリケーションを構築するために必要なステップ（フレームワークの利用、ホスティングサービスへのデプロイ）を説明し、Colabノートブック内でのデータ分析や可視化に関する追加の要望がないかを確認する。

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# No data analysis was performed in this step. The task definition for the final step of the project was established, outlining the need to discuss Colab's limitations in web application development, describe general web application construction steps (including framework usage and deployment to hosting services), and ascertain if there are further requirements for data analysis or visualization within the Colab environment.
#
# ### Insights or Next Steps
# *   The next step is to address the points outlined in the final task definition, providing explanations regarding Colab's capabilities and limitations for web development and detailing the general process for building and deploying web applications.
# *   Following the explanations, it is crucial to confirm with the user if they have any additional requests concerning data analysis or visualization within the Colab notebook.
